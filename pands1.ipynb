# %%
import pandas as pd
#create dadtaframe
df = pd.DataFrame({"Name":['a','b','c','d'], "Age":[12,34,67,43], "Sex":["male","female","male","male"],})
df
# Out:
#   Name  Age     Sex
# 0    a   12    male
# 1    b   34  female
# 2    c   67    male
# 3    d   43    male

# %%
#print age in df
df.Age
# Out:
# 0    12
# 1    34
# 2    67
# 3    43
# Name: Age, dtype: int64

# %%
#print max of age in df
df["Age"].max()
# Out:
# 67

# %%
#print basic statistics of the numerical data of df
df.describe()
# Out:
#              Age
# count   4.000000
# mean   39.000000
# std    22.759613
# min    12.000000
# 25%    28.500000
# 50%    38.500000
# 75%    49.000000
# max    67.000000

# %%
import pandas as pd
#import csv file
week4 = pd.read_csv("week 4 - Sheet1.csv")
#print csv file
week4
# Out:
#      InvoiceNo StockCode                              Product  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 5994    536876     22915          ASSORTED BOTTLE TOP MAGNETS         1
# 5995    536876     22926       IVORY GIANT GARDEN THERMOMETER         1
# 5996    536876     22927       GREEN GIANT GARDEN THERMOMETER         1
# 5997    536876     22943  CHRISTMAS LIGHTS 10 VINTAGE BAUBLES         3
# 5998    536876     22947           WOODEN ADVENT CALENDAR RED         1
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#print basic statistics of the numerical data of imported dataframe
week4.describe()
# Out:
#           Quantity    UnitPrice    CustomerID
# count  5999.000000  5999.000000   4282.000000
# mean      8.495083     4.116578  15866.708547
# std     132.461422    14.267911   1752.168212
# min   -9360.000000     0.000000  12427.000000
# 25%       1.000000     1.250000  14573.000000
# 50%       3.000000     2.510000  15862.000000
# 75%       9.000000     4.250000  17838.000000
# max    2880.000000   607.490000  18239.000000

# %%
#print informations in week4
week4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5999 entries, 0 to 5998
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    5999 non-null   object
#  1   StockCode    5999 non-null   object
#  2   Product      5987 non-null   object
#  3   Quantity     5999 non-null   int64
#  4   InvoiceDate  5999 non-null   object
#  5   UnitPrice    5999 non-null   float64
#  6   CustomerID   4282 non-null   float64
#  7   Country      5999 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 375.1+ KB

# %%
#print the top values of Quantity & CustomerID in week4 csv file 
qu=week4[["Quantity","CustomerID"]]
qu.head()
# Out:
#    Quantity  CustomerID
# 0         6     17850.0
# 1         6     17850.0
# 2         8     17850.0
# 3         6     17850.0
# 4         6     17850.0

# %%
week4["Quantity"].max()
# Out:
# 2880

# %%
#print Quantities greater than 5 from imported csv file
above5=week4[week4["Quantity" ]>5]
above5
# Out:
#      InvoiceNo StockCode                              Product  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 5962    536876     22791         T-LIGHT GLASS FLUTED ANTIQUE         6
# 5975    536876     22835      HOT WATER BOTTLE I AM SO POORLY         9
# 5980    536876     22865               HAND WARMER OWL DESIGN         6
# 5982    536876     22867              HAND WARMER BIRD DESIGN         9
# 5993    536876     22910    PAPER CHAIN KIT VINTAGE CHRISTMAS         9
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#print quantities within 5 & 9 from the imported csv file
abc=week4[week4["Quantity"].isin([5,9])]
abc
# Out:
#      InvoiceNo StockCode                            Product  Quantity  \
# 107     536381     84854                GIRLY PINK TOOL SET         5
# 312     536398     22112         CHOCOLATE HOT WATER BOTTLE         9
# 314     536398     22111       SCOTTIE DOG HOT WATER BOTTLE         9
# 362     536401     20992         JAZZ HEARTS PURSE NOTEBOOK         9
# 372     536401     22467                  GUMBALL COAT RACK         5
# ...        ...       ...                                ...       ...
# 5946    536876     22739  RIBBON REEL CHRISTMAS SOCK BAUBLE         5
# 5975    536876     22835    HOT WATER BOTTLE I AM SO POORLY         9
# 5981    536876     22866      HAND WARMER SCOTTY DOG DESIGN         5
# 5982    536876     22867            HAND WARMER BIRD DESIGN         9
# 5993    536876     22910  PAPER CHAIN KIT VINTAGE CHRISTMAS         9
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# 107     ########       4.95     15311.0  United Kingdom
# ...

# %%
#print Quantities with values 6 & Country with United Kingdom from imported csv file
Qu_Cont=week4[(week4["Quantity"]==6) & (week4["Country"]=='United Kingdom')]
Qu_Cont
# Out:
#      InvoiceNo StockCode                              Product  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 6       536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# ...        ...       ...                                  ...       ...
# 5798    536876     22195         LARGE HEART MEASURING SPOONS         6
# 5836    536876     22348          TEA BAG PLATE RED RETROSPOT         6
# 5907    536876     22588            CARD HOLDER GINGHAM HEART         6
# 5962    536876     22791         T-LIGHT GLASS FLUTED ANTIQUE         6
# 5980    536876     22865               HAND WARMER OWL DESIGN         6
#
#      InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
 #print country equal to france and not equal to united kingdom
    cust_no_na = week4[(week4["Country"]!="United Kingdom" ) & (week4["Country"]=="France")]
    
 cust_no_na
# Out:
#      InvoiceNo StockCode                             Product  Quantity  \
# 26      536370     22728           ALARM CLOCK BAKELIKE PINK        24
# 27      536370     22727            ALARM CLOCK BAKELIKE RED        24
# 28      536370     22726          ALARM CLOCK BAKELIKE GREEN        12
# 29      536370     21724     PANDA AND BUNNIES STICKER SHEET        12
# 30      536370     21883                     STARS GIFT TAPE        24
# 31      536370     10002          INFLATABLE POLITICAL GLOBE        48
# 32      536370     21791   VINTAGE HEADS AND TAILS CARD GAME        24
# 33      536370     21035      SET/2 RED RETROSPOT TEA TOWELS        18
# 34      536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND        24
# 35      536370     22629                  SPACEBOY LUNCH BOX        24
# 36      536370     22659             LUNCH BOX I LOVE LONDON        24
# 37      536370     22631             CIRCUS PARADE LUNCH BOX        24
# ...

# %%
 #to locate the quantiy greater than 6 with country name from impported csv file
    above6 = week4.loc[week4["Quantity"] > 6, 'Country']
    
above6
# Out:
# 2       United Kingdom
# 9       United Kingdom
# 12      United Kingdom
# 26              France
# 27              France
#              ...
# 5934    United Kingdom
# 5956    United Kingdom
# 5975    United Kingdom
# 5982    United Kingdom
# 5993    United Kingdom
# Name: Country, Length: 1682, dtype: object

# %%
#to print from 1 to 25 and 5 to 8
week4.iloc[1:25, 5:8]
# Out:
#     UnitPrice  CustomerID         Country
# 1        3.39     17850.0  United Kingdom
# 2        2.75     17850.0  United Kingdom
# 3        3.39     17850.0  United Kingdom
# 4        3.39     17850.0  United Kingdom
# 5        7.65     17850.0  United Kingdom
# 6        4.25     17850.0  United Kingdom
# 7        1.85     17850.0  United Kingdom
# 8        1.85     17850.0  United Kingdom
# 9        1.69     13047.0  United Kingdom
# 10       2.10     13047.0  United Kingdom
# 11       2.10     13047.0  United Kingdom
# 12       3.75     13047.0  United Kingdom
# 13       1.65     13047.0  United Kingdom
# 14       4.25     13047.0  United Kingdom
# 15       4.95     13047.0  United Kingdom
# 16       9.95     13047.0  United Kingdom
# 17       5.95     13047.0  United Kingdom
# 18       5.95     13047.0  United Kingdom
# 19       7.95     13047.0  United Kingdom
# 20       7.95     13047.0  United Kingdom
# 21       4.25     13047.0  United Kingdom
# ...

# %%
import pandas as pd
#ploting line chart
import matplotlib.pyplot as plt
df = pd.DataFrame({"Name":["aa","bb","cc","dd"], "Age":[12,56,34,45], "Sex":["Male","Female","Male","Male"],})
df.plot()
# Out:
# <AxesSubplot:>

# %%
#plotting box chart
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
#area chart
axs = df.plot.area(figsize=(12, 4), subplots=True)

# %%
 fig, axs = plt.subplots(figsize=(12, 4))
 df.plot.area(ax=axs)
# Out:
# <AxesSubplot:>

# %%
#add column to df
df["after_10_years"] = df["Age"]+10
df
# Out:
#   Name  Age     Sex  after_10_years
# 0   aa   12    Male              22
# 1   bb   56  Female              66
# 2   cc   34    Male              44
# 3   dd   45    Male              55

# %%
#plot with added column
df.plot()
# Out:
# <AxesSubplot:>

# %%
#mean of age
df["Age"].mean()
# Out:
# 36.75

# %%
#median of age & after_10_years
df[["Age","after_10_years"]].median()
# Out:
# Age               39.5
# after_10_years    49.5
# dtype: float64

# %%
df[["Age","after_10_years"]].describe()
# Out:
#              Age  after_10_years
# count   4.000000        4.000000
# mean   36.750000       46.750000
# std    18.786076       18.786076
# min    12.000000       22.000000
# 25%    28.500000       38.500000
# 50%    39.500000       49.500000
# 75%    47.750000       57.750000
# max    56.000000       66.000000

# %%
import pandas as pd

df = pd.DataFrame([[1, 2, 3],

                   [4, 5, 6],

                   [7, 8, 9],

                ],

                  columns=['A', 'B', 'C'])
#aggregate functions
df.agg(["sum",'min','max','mean'])
# Out:
#          A     B     C
# sum   12.0  15.0  18.0
# min    1.0   2.0   3.0
# max    7.0   8.0   9.0
# mean   4.0   5.0   6.0
